# %%
import pandas as pd
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

# %%
df= pd.read_csv("Delitos_en_Bucaramanga_enero_2010_a_diciembre_de_2021_-_HISTORICO.csv", index_col="ORDEN")
df.sample(5)
# Out:
# C:\Users\ansab\AppData\Local\Temp\ipykernel_2964\2808621545.py:1: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("Delitos_en_Bucaramanga_enero_2010_a_diciembre_de_2021_-_HISTORICO.csv", index_col="ORDEN")
#                        ARMAS_MEDIOS BARRIOS_HECHO         LATITUD  \
# ORDEN
# 20613                  CONTUNDENTES       FONTANA        7.082825
# 134129                ARMA DE FUEGO    EL CRISTAL             NaN
# 101342  ARMA BLANCA / CORTOPUNZANTE   CAFE MADRID     7.159129152
# 95447                          MOTO      BOLARQUI        7.109129
# 122417          SIN EMPLEO DE ARMAS        CENTRO  -73,1233163612
#
#             LONGITUD        ZONA              NOM_COMUNA   ANO            MES  \
# ORDEN
# 20613     -73.135543      URBANA            10. Provenza  2012    02. Febrero
# 134129           NaN  NO REPORTA            10. Provenza  2021  11. Noviembre
# 101342  -73.14176641      URBANA               01. Norte  2019      01. Enero
# 95447     -73.114396      URBANA  12. Cabecera del Llano  2018      07. Julio
# 122417  7,1171228038      URBANA              15. Centro  2020  12. Diciembre
#
#         DIA     DIA_SEMANA                               DESCRIPCION_CONDUCTA  \
# ORDEN
# 20613    17    05. Viernes                  ARTÍCULO 111. LESIONES PERSONALES
# 134129   13     06. Sábado                     ARTÍCULO 239. HURTO A PERSONAS
# 101342    5     06. Sábado                     ARTÍCULO 239. HURTO A PERSONAS
# 95447    31     02. Martes  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 122417    2  03. Miércoles                     ARTÍCULO 239. HURTO A PERSONAS
#
#                                               CONDUCTA CLASIFICACIONES DELITO  \
# ORDEN
# 20613                              LESIONES PERSONALES    Lesiones no fatales
# 134129                                HURTO A PERSONAS    Lesiones no fatales
# 101342                                HURTO A PERSONAS    Lesiones no fatales
# 95447   LESIONES CULPOSAS ( EN ACCIDENTE DE TRANSITO )    Lesiones no fatales
# 122417                                HURTO A PERSONAS    Lesiones no fatales
#
#        EDAD     CURSO_DE_VIDA ESTADO_CIVIL_PERSONA      GENERO  \
# ORDEN
# 20613    21       04. Jovenes              SOLTERO    FEMENINO
# 134129   17  03. Adolescencia           NO REPORTA  NO REPORTA
# 101342   29       05. Adultez          UNION LIBRE   MASCULINO
# 95447    17  03. Adolescencia              SOLTERO   MASCULINO
# 122417   52       05. Adultez                VIUDO    FEMENINO
#
#                 MOVIL_AGRESOR       MOVIL_VICTIMA
# ORDEN
# 20613                   A PIE               A PIE
# 134129                  A PIE               A PIE
# 101342                  A PIE  CONDUCTOR VEHICULO
# 95447   CONDUCTOR MOTOCICLETA               A PIE
# 122417                  A PIE        PASAJERO BUS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135076 entries, 1 to 135076
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ARMAS_MEDIOS            135076 non-null  object
#  1   BARRIOS_HECHO           135076 non-null  object
#  2   LATITUD                 128713 non-null  object
#  3   LONGITUD                128713 non-null  object
#  4   ZONA                    135076 non-null  object
#  5   NOM_COMUNA              135076 non-null  object
#  6   ANO                     135076 non-null  int64
#  7   MES                     135076 non-null  object
#  8   DIA                     135076 non-null  int64
#  9   DIA_SEMANA              135076 non-null  object
#  10  DESCRIPCION_CONDUCTA    135076 non-null  object
#  11  CONDUCTA                135076 non-null  object
#  12  CLASIFICACIONES DELITO  135076 non-null  object
#  13  EDAD                    135076 non-null  object
#  14  CURSO_DE_VIDA           135076 non-null  object
#  15  ESTADO_CIVIL_PERSONA    135076 non-null  object
#  16  GENERO                  135076 non-null  object
#  17  MOVIL_AGRESOR           135076 non-null  object
#  18  MOVIL_VICTIMA           135076 non-null  object
# dtypes: int64(2), object(17)
# memory usage: 20.6+ MB

# %%
#valores nulos
df.isnull().sum()
# Out:
# ARMAS_MEDIOS                 0
# BARRIOS_HECHO                0
# LATITUD                   6363
# LONGITUD                  6363
# ZONA                         0
# NOM_COMUNA                   0
# ANO                          0
# MES                          0
# DIA                          0
# DIA_SEMANA                   0
# DESCRIPCION_CONDUCTA         0
# CONDUCTA                     0
# CLASIFICACIONES DELITO       0
# EDAD                         0
# CURSO_DE_VIDA                0
# ESTADO_CIVIL_PERSONA         0
# GENERO                       0
# MOVIL_AGRESOR                0
# MOVIL_VICTIMA                0
# dtype: int64

# %%
# Eliminar de la columna mes el nombre y en dia_semana el numero
df['MES'] = df['MES'].str[0:2]   
df["DIA_SEMANA"]=df["DIA_SEMANA"].str[4:]
df.sample(5)
# Out:
#                        ARMAS_MEDIOS     BARRIOS_HECHO       LATITUD  \
# ORDEN
# 126987  ARMA BLANCA / CORTOPUNZANTE            CENTRO  7.1217752526
# 7039                  ARMA DE FUEGO   NUEVO SOTOMAYOR      7.123219
# 38355                 ARMA DE FUEGO    PUERTA DEL SOL      7.100572
# 34660                  CONTUNDENTES           CONUCOS      7.100572
# 99668                          MOTO  URB. BALCONCITOS   7.104444191
#
#               LONGITUD    ZONA              NOM_COMUNA   ANO MES  DIA  \
# ORDEN
# 126987  -73.1250783047  URBANA              15. Centro  2021  04    8
# 7039        -73.114929  URBANA  12. Cabecera del Llano  2010  10   22
# 38355       -73.117362  URBANA  12. Cabecera del Llano  2013  10    4
# 34660       -73.117362  URBANA  12. Cabecera del Llano  2013  06    9
# 99668     -73.13066475  URBANA               17. Mutis  2018  11   21
#
#        DIA_SEMANA                               DESCRIPCION_CONDUCTA  \
# ORDEN
# 126987     Jueves                  ARTÍCULO 111. LESIONES PERSONALES
# 7039      Viernes                     ARTÍCULO 239. HURTO A PERSONAS
# 38355     Viernes                     ARTÍCULO 239. HURTO A PERSONAS
# 34660     Domingo                  ARTÍCULO 111. LESIONES PERSONALES
# 99668   Miércoles  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
#
#                                               CONDUCTA CLASIFICACIONES DELITO  \
# ORDEN
# 126987                             LESIONES PERSONALES    Lesiones no fatales
# 7039                                  HURTO A PERSONAS    Lesiones no fatales
# 38355                                 HURTO A PERSONAS    Lesiones no fatales
# 34660                              LESIONES PERSONALES    Lesiones no fatales
# 99668   LESIONES CULPOSAS ( EN ACCIDENTE DE TRANSITO )    Lesiones no fatales
#
#        EDAD CURSO_DE_VIDA ESTADO_CIVIL_PERSONA     GENERO  \
# ORDEN
# 126987   18   04. Jovenes           NO REPORTA  MASCULINO
# 7039     49   05. Adultez               CASADO  MASCULINO
# 38355    20   04. Jovenes              SOLTERO  MASCULINO
# 34660    23   04. Jovenes              SOLTERO   FEMENINO
# 99668    53   05. Adultez               CASADO  MASCULINO
#
#                 MOVIL_AGRESOR       MOVIL_VICTIMA
# ORDEN
# 126987                  A PIE               A PIE
# 7039    CONDUCTOR MOTOCICLETA  CONDUCTOR VEHICULO
# 38355                   A PIE               A PIE
# 34660                   A PIE               A PIE
# 99668   CONDUCTOR MOTOCICLETA               A PIE

# %%
# Creamos una columna fecha usando columnas ano mes dia
df["ANO"]=df["ANO"].astype(str)
df["MES"]=df["MES"].astype(str)
df["DIA"]=df["DIA"].astype(str)
df["FECHA"]=df["ANO"]+"-"+df["MES"]+"-"+df["DIA"]
df["FECHA"]=pd.to_datetime(df["FECHA"])
df.sample(5)
# Out:
#                        ARMAS_MEDIOS            BARRIOS_HECHO       LATITUD  \
# ORDEN
# 111446  ARMA BLANCA / CORTOPUNZANTE                   CENTRO   7.123499524
# 39963           SIN EMPLEO DE ARMAS                SOTOMAYOR      7.112873
# 129764  ARMA BLANCA / CORTOPUNZANTE            VILLA ALEGRIA  7.1599746855
# 7901            SIN EMPLEO DE ARMAS                   CENTRO      7.178046
# 48055                  CONTUNDENTES  CIUDADELA REAL DE MINAS      7.103133
#
#               LONGITUD    ZONA              NOM_COMUNA   ANO MES DIA  \
# ORDEN
# 111446    -73.12865148  URBANA              15. Centro  2019  11  17
# 39963       -73.112584  URBANA  12. Cabecera del Llano  2013  11  30
# 129764  -73.1381029441  URBANA               01. Norte  2021  06  20
# 7901        -73.130224  URBANA              15. Centro  2010  11  26
# 48055       -73.123963  URBANA        07. La Ciudadela  2014  09  27
#
#        DIA_SEMANA               DESCRIPCION_CONDUCTA             CONDUCTA  \
# ORDEN
# 111446    Domingo     ARTÍCULO 239. HURTO A PERSONAS     HURTO A PERSONAS
# 39963      Sábado     ARTÍCULO 239. HURTO A PERSONAS     HURTO A PERSONAS
# 129764    Domingo     ARTÍCULO 239. HURTO A PERSONAS     HURTO A PERSONAS
# 7901      Viernes     ARTÍCULO 239. HURTO A PERSONAS     HURTO A PERSONAS
# 48055      Sábado  ARTÍCULO 111. LESIONES PERSONALES  LESIONES PERSONALES
#
#        CLASIFICACIONES DELITO EDAD      CURSO_DE_VIDA ESTADO_CIVIL_PERSONA  \
# ORDEN
# 111446    Lesiones no fatales   61  06. Persona Mayor              SOLTERO
# 39963     Lesiones no fatales   33        05. Adultez              SOLTERO
# 129764    Lesiones no fatales   25        04. Jovenes           NO REPORTA
# 7901      Lesiones no fatales   34        05. Adultez              SOLTERO
# 48055     Lesiones no fatales   37        05. Adultez              SOLTERO
#
#             GENERO MOVIL_AGRESOR MOVIL_VICTIMA      FECHA
# ORDEN
# 111446   MASCULINO         A PIE         A PIE 2019-11-17
# 39963     FEMENINO         A PIE         A PIE 2013-11-30
# 129764  NO REPORTA         A PIE         A PIE 2021-06-20
# 7901      FEMENINO         A PIE         A PIE 2010-11-26
# 48055     FEMENINO         A PIE         A PIE 2014-09-27

# %%
# cantidad de crimenes por genero
df["GENERO"].value_counts()
# Out:
# GENERO
# MASCULINO     63560
# FEMENINO      56411
# NO REPORTA    15105
# Name: count, dtype: int64

# %%
# armas usadas en delitos
df["ARMAS_MEDIOS"].value_counts()
# Out:
# ARMAS_MEDIOS
# SIN EMPLEO DE ARMAS                   38265
# CONTUNDENTES                          37023
# ARMA BLANCA / CORTOPUNZANTE           21890
# VEHICULO                              13419
# ARMA DE FUEGO                          8947
# MOTO                                   7919
# LLAVE MAESTRA                          2500
# NO REPORTADO                           2113
# PALANCAS                               1078
# ESCOPOLAMINA                            656
# LLAMADA TELEFONICA                      278
# PUNZANTES                               248
# CORTANTES                               123
# PERRO                                    84
# REDES SOCIALES                           68
# DIRECTA                                  65
# ACIDO                                    51
# BICICLETA                                45
# MIXTA                                    45
# LICOR ADULTERADO                         36
# CORTOPUNZANTES                           33
# GASES                                    18
# ARMA TRAUMATICA                          17
# QUIMICOS                                 17
# SUSTANCIAS TOXICAS                       17
# AGUA CALIENTE                            17
# COMBUSTIBLE                              14
# MEDICAMENTOS                             13
# ARTEFACTO INCENDIARIO                    12
# PAPA EXPLOSIVA                            9
# CARTA EXTORSIVA                           8
# GRANADA DE MANO                           8
# JERINGA                                   8
# CARRO BOMBA                               7
# CUCHILLA                                  6
# CINTAS/CINTURON                           5
# VENENO                                    5
# PRENDAS DE VESTIR                         3
# BOLSA PLASTICA                            2
# CUERDA/SOGA/CADENA                        1
# ARTEFACTO EXPLOSIVO/CARGA DINAMITA        1
# POLVORA(FUEGOS PIROTECNICOS)              1
# ALUCINOGENOS                              1
# Name: count, dtype: int64

# %%
# primer y ultimo delito registrado en bucaramanga
earliest = df["FECHA"].min()
latest = df["FECHA"].max()
print("Primer delito registrado:", earliest)
print("Ultimo delito registrado:", latest)
# Out:
# Primer delito registrado: 2010-01-01 00:00:00
# Ultimo delito registrado: 2021-12-31 00:00:00

# %%
# grafico de barras de la cantidad de crimenes en cada año y circular para porcentaje que tiene cada año usando altair
df_count = df.groupby("ANO").size().reset_index(name="count")

bars = alt.Chart(df_count).mark_bar().encode(
    x=alt.X("ANO:O", title="Año"),
    y=alt.Y("count:Q", title="Cantidad de delitos"),
    
).properties(
    width=600,
    height=400,
    title="Cantidad de delitos por año"
)

# Gráfico de texto para los números de delitos
text_bars = bars.mark_text(
    align='center',
    baseline='bottom',
).encode(
    text='count:Q'
)

# Superponer el gráfico de texto en el gráfico de barras
chart_bar = bars + text_bars

# Grafico circular 
total_crime = df_count["count"].sum()
df_count["percent"] = (df_count["count"] / total_crime) * 100
pie = alt.Chart(df_count).mark_arc().encode(
    theta="percent:Q",
    color="ANO:N",
).properties(
    width=600,
    height=400,
    title="Porcentaje de delitos por año"
)
text_pie = pie.mark_text(
    radius=150,
    align='center',
    baseline='middle',
    fontSize=15,
).encode(
    text=alt.Text("percent:N", format=".2f"),
    color=alt.value("black"),\
    theta=alt.Theta('percent:Q', stack=True)
)
chart_pie = pie + text_pie
graph = alt.hconcat(chart_bar, chart_pie)

graph
# Out:
# alt.HConcatChart(...)
